# %% [markdown]
# <a href="https://colab.research.google.com/github/Roohiashahzad/Roohia_INFO5731_Spring2020/blob/main/Final_Data_Visualization_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
data = pd.read_csv('/content/Final_TrainData_ACL&ALL.csv') #Training/labeled data file 
data.head()
# Out:
#                                                Title  ...                                          Labels
# 0  Text Mining for Personalized Knowledge Extract...  ...  Algorithm or Method or Technology Optimization
# 1  Text Mining for Personalized Knowledge Extract...  ...           New Algorithm or Method or Technology
# 2  Text Mining for Personalized Knowledge Extract...  ...                          Performance Evaluation
# 3  PSI: A probabilistic semantic interpretable fr...  ...                              Model Construction
# 4  PSI: A probabilistic semantic interpretable fr...  ...  Algorithm or Method or Technology Optimization
#
# [5 rows x 4 columns]

# %% [markdown]
# # Visulising the Annotation result from JASST, IPM ,and ACL

# %%
data['Labels'] = data['Labels'].apply(lambda x: " ".join(x.upper() for x in x.split()))
data['Labels'].describe()
# Out:
# count                3133
# unique                  9
# top       THEORY PROPOSAL
# freq                  800
# Name: Labels, dtype: object

# %%
print(data['Labels'].value_counts())
# Out:
# THEORY PROPOSAL                                   800
# NEW ALGORITHM OR METHOD OR TECHNOLOGY             687
# PERFORMANCE EVALUATION                            470
# MODEL CONSTRUCTION                                328
# RESOURCES                                         296
# MODEL OPTIMIZATION                                161
# ALGORITHM OR METHOD OR TECHNOLOGY OPTIMIZATION    151
# DATASET CREATION                                  125
# APPLICATIONS                                      115
# Name: Labels, dtype: int64

# %%
for Sour, Count in enumerate(data['Source'].value_counts().index.tolist()):
    print('Contributions',  Count)
    print('Counts :', (data['Labels'].value_counts()[Sour]))

# %%
data['Labels'] = data['Labels'].apply(lambda x: " ".join(x.upper() for x in x.split()))
data['Labels'].value_counts().plot(kind='barh', figsize=(10, 4), rot=0)
plt.title("The Distribution of Research Contributions From IPM, JASIST,and ACL In All Categories ", y=1.02)
# Out:
# Text(0.5, 1.02, 'The Distribution of Research Contributions From IPM, JASIST,and ACL In All Categories ')

# %%
Colors=['red', 'yellow','blue', 'green',  'pink', 'gray','violet', 'orange','maroon']

Data3 = data['Labels'].value_counts().keys().tolist()
Valcount = data['Labels'].value_counts().tolist()
plt.pie(Valcount,labels=Data3, colors=Colors, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # IPM Visualization

# %%
Colors=['red', 'yellow','blue', 'green',  'pink', 'black','violet', 'orange','azure']
IPM_data= pd.read_csv('/content/IPM_Labels.csv')
IPM_data['Labels'] = IPM_data['Labels'].apply(lambda x: " ".join(x.upper() for x in x.split()))
IPM_data['Labels'].count()
# Out:
# 998

# %%
import matplotlib.pyplot as plt
% matplotlib inline
import seaborn as sns
plt.figure (figsize = (10,4)) 
IPM = sns.countplot (y = IPM_data['Labels'],data=IPM_data, order=IPM_data['Labels'].value_counts().index)
plt.title("The Distribution of Research Contributions From IPM", y=1.02)
# Out:
# Text(0.5, 1.02, 'The Distribution of Research Contributions From IPM')

# %%
import pandas as pd
import matplotlib.pyplot as plt

IPM_Value = IPM_data['Labels'].value_counts().keys().tolist()
IPM_Count = IPM_data['Labels'].value_counts().tolist()
plt.pie(IPM_Count, labels=IPM_Value, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # JASIST Visualization

# %%
JAS_data= pd.read_csv('/content/JASIST_Labels.csv')
JAS_data['Labels'].count()
# Out:
# 1002

# %%
JAS_data['Labels'] = JAS_data['Labels'].apply(lambda x: " ".join(x.upper() for x in x.split()))
plt.figure (figsize = (10,4)) 
JAS = sns.countplot (y = JAS_data['Labels'],data=JAS_data, order=JAS_data['Labels'].value_counts().index)
plt.title("The Distribution of Research Contributions From JASIST", y=1.02)
# Out:
# Text(0.5, 1.02, 'The Distribution of Research Contributions From JASIST')

# %%
New_Colors=[ 'yellow','lightblue', 'green', 'orange', 'brown', 'lightseagreen', 'pink','magenta', 'aliceblue']
JAS_Value = JAS_data['Labels'].value_counts().keys().tolist()
JAS_Count = JAS_data['Labels'].value_counts().tolist()
plt.pie(JAS_Count, labels=JAS_Value,colors=New_Colors, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %% [markdown]
# # ACL Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
ACL_data= pd.read_csv("/content/ACL_Labels1.csv")
ACL_data['Labels'] = ACL_data['Labels'].apply(lambda x: " ".join(x.upper() for x in x.split()))
ACL_data['Labels'].count()
# Out:
# 1133

# %%
ACL_data['Labels'] = ACL_data['Labels'].apply(lambda x: " ".join(x.upper() for x in x.split()))
plt.figure (figsize = (10,4)) 
ACL = sns.countplot (y = ACL_data['Labels'],data=ACL_data, order=ACL_data['Labels'].value_counts().index)
plt.title("The Distribution of Research Contributions From ACL", y=1.02)
# Out:
# Text(0.5, 1.02, 'The Distribution of Research Contributions From ACL')

# %%
ACL_Value = ACL_data['Labels'].value_counts().keys().tolist()
ACL_Count = ACL_data['Labels'].value_counts().tolist()
plt.pie(ACL_Count, labels=ACL_Value,colors=Colors, autopct='%1.1f%%')
plt.axis('equal')
plt.show()
